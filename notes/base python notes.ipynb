# %% [markdown]
# _remove_ removes the first matching value, not a specific index:
#
# > a = [0, 2, 3, 2]
# > a.remove(2)
# > a
# [0, 3, 2]
#
# _del_ removes the item at a specific index:
#
# > a = [3, 2, 2, 1]
# > del a[1]
# > a
# [3, 2, 1]
#
# _pop_ removes the item at a specific index and returns it.
#
# > a = [4, 3, 5]
# > a.pop(1)
# 3
# > a
# [4, 5]

# %% [markdown]
# #### Variables
#
#
# () - An immutable collection of values, usually (but not necessarily) of different types.
# [] is a list: A mutable collection of values, usually (but not necessarily) of the same type.
# {} - dictionary; {} is either a dictionary ({"a":"1","b":"2"}) or a set ({"a","b","c"}). A set is an unordered collection of unique values, which can be changed (although each item in it can't)

# %% [markdown]
# ## original notes, need formatted
#
#
# None used for null
#
# Avoid nonhierarchical invents
#
# Print.format syntax
# indexes on lists start at 0
#
# While a list stores that data as an ordered sequence, dictionaries store that data as an unordered collection of key:value pairs.
#
# adventurer = {"name": "grae", "profession": "magician"}
# To access,
# adventurer["name"]
# Determinacy
# 	• Math shows one-to-one input/output mapping for function. Not required in programming.
# 	• Indeterminate function affected by parts of program beyond the input/output. Harder to use/read b/c need to remember state.
# 	• Also bad is affecting state beyond the input/output: causing Side Effects
# In general,
# function(input)
#     DoThingsWithInput
#     Return output
# Booleans evaluate arguments in order. Reason?to make this functional:
#     person = person or 'world'
# And/Or evaluate first variable, if true/false go on to next. Return first or last.
#
# ### LOOPS
#
#     For loop: For Item in List
#     >>> names = ["Bethany", "Alex", "Grae"]
# >>> for name in names:
# >>>     greeting = "Hello " + name
# >>>     print(greeting)
#     Note that highlighted is each loops variable from the list.
#
#     From <https://courses.thinkful.com/dsbc-fundamentals-v1/checkpoint/11>
#     Use when want to apply opersations to all values in a set of values, or want to perform a set number of times
#
#     While loop: While Condition
# 			Code
#
# Evaluate: <=
# Iterate:    +=
#
# View objects are dynamic.
#
# 	>>> stock = {"apples": 5, "oranges": 2}
# >>> items_for_sale = stock.keys()
# >>> stock["pears"] = 10
# >>> items_for_sale
# dict_keys(['pears', 'oranges', 'apples'])
#
# 	From <https://courses.thinkful.com/dsbc-fundamentals-v1/checkpoint/12>
# "Method" is in fact just the special name we use for functions that are attached to an object as one of the object's attributes.
#
# Class = platonic form; instance = thing that participates in the form.
#
# JSON stands for "JavaScript Object Notation" and is a way to represent a JavaScript object as a string. "Objects" in JavaScript are just collections of key-value pairs, exactly like Python dictionaries. Almost everything you know about Python dictionaries translates directly to JavaScript objects, so you can imagine that "JSON" stands for "Python Dictionary Notation" and treat JSON as if it's a string representation of a Python dictionary.
# 	• Standard deviation = spread and variability of the data
# 	• Standard error of the mean = precision of the mean, confidence intervals around estimated means. ALSO to test (in terms of null hypothesis testing) differences between means
# The DataFrame class resembles a collection of NumPy arrays but with labeled axes and mixed data types across the columns. In fact, Series is subclass of NumPy’s ndarray.
#
# ##Probability
#
# frequentists are trying to calculate the likelihood of getting the data you have in the context of a fixed, if unknown, "true" population value. Bayesians are trying to calculate the most likely population value, given the data you have.
#
# Pipe: A|B is probability of A, given B.
#
# Probability of two conditional events can be broken down into:
# P(A ∩ B) = P(A) * P(B | A)
# Bayes' rule:
#
# P(A | B) = P(B | A) * P(A) / P(B)
# OR
# P(A | B) = P(B | A) * P(A) / [P(A)*P(B|A) + P(A~)*P(B|A~)]
